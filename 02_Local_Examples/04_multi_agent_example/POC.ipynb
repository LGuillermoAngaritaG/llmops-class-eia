# %% [markdown]
# # Summary
#
# In this use case we are going to use crewai to generate code

# %% [markdown]
# # CrewAi Architecture

# %%
# !pip install crewai duckduckgo-search
# Out:
# Looking in indexes: https://pypi.org/simple, https://luisangarita.gutierrez-contractor%40procore.com:****@artifacts.procoretech.com/artifactory/api/pypi/python/simple
# Requirement already satisfied: crewai in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (0.80.0)
# Collecting duckduckgo-search
#   Downloading https://artifacts.procoretech.com/artifactory/api/pypi/python/packages/packages/b7/f9/e0c55a56d63bbb42218fee86a4486c001834b31ec5bfc23a365749262ce3/duckduckgo_search-6.3.5-py3-none-any.whl (27 kB)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.4.4)
# Requirement already satisfied: auth0-python>=4.7.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (4.7.2)
# Requirement already satisfied: chromadb>=0.4.24 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.5.20)
# Requirement already satisfied: click>=8.1.7 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (8.1.7)
# Requirement already satisfied: crewai-tools>=0.14.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.14.0)
# Requirement already satisfied: instructor>=1.3.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.6.4)
# Requirement already satisfied: json-repair>=0.25.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.30.2)
# Requirement already satisfied: jsonref>=1.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: langchain>=0.2.16 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.3.7)
# Requirement already satisfied: litellm>=1.44.22 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.52.10)
# Requirement already satisfied: openai>=1.13.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.54.5)
# Requirement already satisfied: opentelemetry-api>=1.22.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.28.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-http>=1.22.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.28.2)
# Requirement already satisfied: opentelemetry-sdk>=1.22.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.28.2)
# Requirement already satisfied: pydantic>=2.4.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (2.9.2)
# Requirement already satisfied: python-dotenv>=1.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.0.1)
# Requirement already satisfied: pyvis>=0.3.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.3.2)
# Requirement already satisfied: regex>=2024.9.11 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (2024.11.6)
# Requirement already satisfied: tomli-w>=1.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (1.1.0)
# Requirement already satisfied: tomli>=2.0.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (2.1.0)
# Requirement already satisfied: uv>=0.4.25 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai) (0.5.2)
# Collecting primp>=0.6.5 (from duckduckgo-search)
#   Downloading https://artifacts.procoretech.com/artifactory/api/pypi/python/packages/packages/48/41/926045899d5895ec35a847c1932aee609232915f3d55bc1cec72322c0891/primp-0.7.0-cp38-abi3-macosx_11_0_arm64.whl (2.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 4.5 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai) (3.11.4)
# Requirement already satisfied: cryptography<44.0.0,>=43.0.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai) (43.0.3)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai) (2.10.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai) (2.32.3)
# Requirement already satisfied: urllib3<3.0.0,>=2.0.7 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from auth0-python>=4.7.1->crewai) (2.2.3)
# Requirement already satisfied: build>=1.0.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (1.2.2.post1)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.115.5)
# Requirement already satisfied: uvicorn>=0.18.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai) (0.32.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (4.12.2)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (1.20.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (1.28.2)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.49b2)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.20.3)
# Requirement already satisfied: pypika>=0.48.9 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (4.67.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (6.4.5)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (1.68.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.13.1)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (31.0.0)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (6.0.2)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (5.0.1)
# Requirement already satisfied: orjson>=3.9.12 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (3.10.11)
# Requirement already satisfied: httpx>=0.27.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (0.27.2)
# Requirement already satisfied: rich>=10.11.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from chromadb>=0.4.24->crewai) (13.9.4)
# Requirement already satisfied: beautifulsoup4>=4.12.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (4.12.3)
# Requirement already satisfied: docker>=7.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (7.1.0)
# Requirement already satisfied: docx2txt>=0.8 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (0.8)
# Requirement already satisfied: embedchain>=0.1.114 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (0.1.125)
# Requirement already satisfied: lancedb>=0.5.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (0.16.0)
# Requirement already satisfied: pyright>=1.1.350 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (1.1.389)
# Requirement already satisfied: pytest>=8.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (8.3.3)
# Requirement already satisfied: pytube>=15.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (15.0.0)
# Requirement already satisfied: selenium>=4.18.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from crewai-tools>=0.14.0->crewai) (4.26.1)
# Requirement already satisfied: docstring-parser<0.17,>=0.16 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (0.16)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (3.1.4)
# Requirement already satisfied: jiter<0.7,>=0.6.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (0.6.1)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from instructor>=1.3.3->crewai) (2.23.4)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain>=0.2.16->crewai) (2.0.35)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.15 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain>=0.2.16->crewai) (0.3.19)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain>=0.2.16->crewai) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain>=0.2.16->crewai) (0.1.143)
# Requirement already satisfied: importlib-metadata>=6.8.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from litellm>=1.44.22->crewai) (8.5.0)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from litellm>=1.44.22->crewai) (4.23.0)
# Requirement already satisfied: tiktoken>=0.7.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from litellm>=1.44.22->crewai) (0.7.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from openai>=1.13.3->crewai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from openai>=1.13.3->crewai) (1.9.0)
# Requirement already satisfied: sniffio in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from openai>=1.13.3->crewai) (1.3.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-api>=1.22.0->crewai) (1.2.15)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.66.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.28.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.28.2)
# Requirement already satisfied: opentelemetry-proto==1.28.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (1.28.2)
# Requirement already satisfied: protobuf<6.0,>=5.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-proto==1.28.2->opentelemetry-exporter-otlp-proto-http>=1.22.0->crewai) (5.28.3)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.49b2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-sdk>=1.22.0->crewai) (0.49b2)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pydantic>=2.4.2->crewai) (0.7.0)
# Requirement already satisfied: ipython>=5.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (8.29.0)
# Requirement already satisfied: jsonpickle>=1.4.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (4.0.0)
# Requirement already satisfied: networkx>=1.11 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pyvis>=0.3.2->crewai) (3.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.5->auth0-python>=4.7.1->crewai) (1.17.2)
# Requirement already satisfied: idna>=2.8 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai>=1.13.3->crewai) (3.10)
# Requirement already satisfied: soupsieve>1.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from beautifulsoup4>=4.12.3->crewai-tools>=0.14.0->crewai) (2.6)
# Requirement already satisfied: packaging>=19.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.4.24->crewai) (24.2)
# Requirement already satisfied: pyproject_hooks in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from build>=1.0.3->chromadb>=0.4.24->crewai) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (1.17.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.22.0->crewai) (1.16.0)
# Requirement already satisfied: alembic<2.0.0,>=1.13.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.14.0)
# Requirement already satisfied: cohere<6.0,>=5.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (5.11.4)
# Requirement already satisfied: google-cloud-aiplatform<2.0.0,>=1.26.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.72.0)
# Requirement already satisfied: gptcache<0.2.0,>=0.1.43 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.1.44)
# Requirement already satisfied: langchain-cohere<0.4.0,>=0.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.3.1)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.3.7)
# Requirement already satisfied: langchain-openai<0.3.0,>=0.2.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.2.9)
# Requirement already satisfied: mem0ai<0.2.0,>=0.1.29 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.1.29)
# Requirement already satisfied: pypdf<6.0.0,>=5.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (5.1.0)
# Requirement already satisfied: pysbd<0.4.0,>=0.3.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.3.4)
# Requirement already satisfied: schema<0.8.0,>=0.7.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.7.7)
# Requirement already satisfied: starlette<0.42.0,>=0.40.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb>=0.4.24->crewai) (0.41.3)
# Requirement already satisfied: certifi in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.4.24->crewai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb>=0.4.24->crewai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb>=0.4.24->crewai) (0.14.0)
# Requirement already satisfied: zipp>=3.20 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from importlib-metadata>=6.8.0->litellm>=1.44.22->crewai) (3.21.0)
# Requirement already satisfied: decorator in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (3.0.48)
# Requirement already satisfied: pygments>=2.4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.18.0)
# Requirement already satisfied: stack-data in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (5.14.3)
# Requirement already satisfied: pexpect>4.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from ipython>=5.3.0->pyvis>=0.3.2->crewai) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.1.4->instructor>=1.3.3->crewai) (3.0.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm>=1.44.22->crewai) (0.21.0)
# Requirement already satisfied: six>=1.9.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (2.36.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (1.8.0)
# Requirement already satisfied: requests-oauthlib in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (3.2.2)
# Requirement already satisfied: durationpy>=0.7 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (0.9)
# Requirement already satisfied: deprecation in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai) (2.1.0)
# Requirement already satisfied: nest-asyncio~=1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai) (1.6.0)
# Requirement already satisfied: pylance==0.19.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from lancedb>=0.5.4->crewai-tools>=0.14.0->crewai) (0.19.2)
# Requirement already satisfied: pyarrow>=12 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pylance==0.19.2->lancedb>=0.5.4->crewai-tools>=0.14.0->crewai) (18.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.15->langchain>=0.2.16->crewai) (1.33)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain>=0.2.16->crewai) (1.0.0)
# Requirement already satisfied: coloredlogs in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai) (24.3.25)
# Requirement already satisfied: sympy in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb>=0.4.24->crewai) (1.13.3)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.49b2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai) (0.49b2)
# Requirement already satisfied: opentelemetry-instrumentation==0.49b2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai) (0.49b2)
# Requirement already satisfied: opentelemetry-util-http==0.49b2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai) (0.49b2)
# Requirement already satisfied: asgiref~=3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.49b2->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb>=0.4.24->crewai) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.24->crewai) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb>=0.4.24->crewai) (2.2.1)
# Requirement already satisfied: nodeenv>=1.6.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pyright>=1.1.350->crewai-tools>=0.14.0->crewai) (1.9.1)
# Requirement already satisfied: iniconfig in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pytest>=8.0.0->crewai-tools>=0.14.0->crewai) (2.0.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pytest>=8.0.0->crewai-tools>=0.14.0->crewai) (1.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from requests<3.0.0,>=2.31.0->auth0-python>=4.7.1->crewai) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from rich>=10.11.0->chromadb>=0.4.24->crewai) (3.0.0)
# Requirement already satisfied: trio~=0.17 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (0.27.0)
# Requirement already satisfied: trio-websocket~=0.9 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (0.11.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from tokenizers>=0.13.2->chromadb>=0.4.24->crewai) (0.26.2)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from typer>=0.9.0->chromadb>=0.4.24->crewai) (1.5.4)
# Requirement already satisfied: httptools>=0.5.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai) (0.6.4)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb>=0.4.24->crewai) (14.1)
# Requirement already satisfied: Mako in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from alembic<2.0.0,>=1.13.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.3.6)
# Requirement already satisfied: pycparser in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cffi>=1.12->cryptography<44.0.0,>=43.0.1->auth0-python>=4.7.1->crewai) (2.22)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.9.7)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.4.0)
# Requirement already satisfied: parameterized<0.10.0,>=0.9.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.9.0)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from cohere<6.0,>=5.3->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.32.0.20241016)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (4.9)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.23.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.25.0)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.18.2)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (3.27.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.13.1)
# Requirement already satisfied: shapely<3.0.0dev in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.0.6)
# Requirement already satisfied: filelock in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb>=0.4.24->crewai) (2024.10.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jedi>=0.16->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.8.4)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.15->langchain>=0.2.16->crewai) (3.0.0)
# Requirement already satisfied: langchain-experimental>=0.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.3.3)
# Requirement already satisfied: pandas>=1.4.3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.2.3)
# Requirement already satisfied: tabulate<0.10.0,>=0.9.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.9.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.6.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb>=0.4.24->crewai) (0.1.2)
# Requirement already satisfied: pytz<2025.0,>=2024.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2024.2)
# Requirement already satisfied: qdrant-client<2.0.0,>=1.9.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.12.1)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pexpect>4.3->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.13)
# Requirement already satisfied: sortedcontainers in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (2.4.0)
# Requirement already satisfied: outcome in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from trio~=0.17->selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (1.3.0.post0)
# Requirement already satisfied: wsproto>=0.14 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium>=4.18.1->crewai-tools>=0.14.0->crewai) (1.7.1)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb>=0.4.24->crewai) (10.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (2.4.1)
# Requirement already satisfied: pure-eval in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from stack-data->ipython>=5.3.0->pyvis>=0.3.2->crewai) (0.2.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb>=0.4.24->crewai) (1.3.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.9.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.34.1->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.68.0)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=2.4.1 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.4.1)
# Requirement already satisfied: google-resumable-media<3.0dev,>=2.0.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-bigquery!=3.20.0,<4.0.0dev,>=1.15.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.7.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (0.13.1)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform<2.0.0,>=1.26.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.6.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pandas>=1.4.3->langchain-cohere<0.4.0,>=0.3.0->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2024.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb>=0.4.24->crewai) (0.6.1)
# Requirement already satisfied: grpcio-tools>=1.41.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.68.0)
# Requirement already satisfied: portalocker<3.0.0,>=2.7.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (2.10.1)
# Requirement already satisfied: setuptools in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from grpcio-tools>=1.41.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (75.5.0)
# Requirement already satisfied: h2<5,>=3 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (4.1.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.1->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (1.0.0)
# Requirement already satisfied: hyperframe<7,>=6.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (6.0.1)
# Requirement already satisfied: hpack<5,>=4.0 in /Users/ganga/mambaforge/envs/llmops/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]>=0.20.0->qdrant-client<2.0.0,>=1.9.1->mem0ai<0.2.0,>=0.1.29->embedchain>=0.1.114->crewai-tools>=0.14.0->crewai) (4.0.0)
# Installing collected packages: primp, duckduckgo-search
# Successfully installed duckduckgo-search-6.3.5 primp-0.7.0

# %%
from crewai import Agent, Task, Crew
# from custom_agent import CustomAgent # You need to build and extend your own agent logic with the CrewAI BaseAgent class then import it here.
from langchain_groq import ChatGroq
from langchain.agents import load_tools
from langchain.agents import Tool
from dotenv import load_dotenv
from langchain_community.tools import DuckDuckGoSearchRun
import os

load_dotenv()

from crewai import LLM

groq_llm = LLM(
    model="groq/llama3-8b-8192",
    api_key=os.getenv("GROQ_API_KEY")
)

agent1 = Agent(
    role="agent role",
    goal="who is {input}?",
    backstory="agent backstory",
    verbose=True,
    llm=groq_llm,
)

task1 = Task(
    expected_output="a short biography of {input}",
    description="a short biography of {input}",
    agent=agent1,)

agent2 = Agent(
    role="agent role",
    goal="summarize the short bio for {input} and if needed do more research",
    backstory="agent backstory",
    verbose=True,
    llm=groq_llm,
)

task2 = Task(
    description="a tldr summary of the short biography",
    expected_output="5 bullet point summary of the biography",
    agent=agent2,
    context=[task1],
)

my_crew = Crew(agents=[agent1, agent2], tasks=[task1, task2])
crew = my_crew.kickoff(inputs={"input": "Mark Twain"})
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: agent role
# ## Task: a short biography of Mark Twain
#
#
# # Agent: agent role
# ## Final Answer:
# Samuel Langhorne Clemens, better known by his pen name Mark Twain, was a renowned American author and humorist born on November 30, 1835, in Florida, Missouri. He grew up in Hannibal, Missouri, a riverside town that would later serve as the inspiration for the fictional Tom Sawyer's hometown. Clemens developed a fascination with steamboats and the Mississippi River, which played a significant role in shaping his literary career.
#
# Before pursuing a career in writing, Clemens worked as a typesetter, a riverboat pilot, and a journalist. He began his writing career as a newspaper reporter, eventually moving to Nevada and working as a correspondent for the Virginia City Territorial Enterprise. This period saw the birth of his pen name, Mark Twain, which was derived from his habit of calling out "mark twain" when measuring the depth of the water while piloting his steamboat.
#
# Twain's most famous works include "The Adventures of Tom Sawyer" (1876) and "The Adventures of Huckleberry Finn" (1885). These novels, often considered classics of American literature, dealt with themes of childhood innocence, social commentary, and racial issues. His writing style, characterized by its wit, satire, and humor, has made him one of the most beloved and respected American authors of all time.
#
# Throughout his life, Twain was an advocate for social justice, often publicly speaking out against issues such as slavery, racism, and corruption. He was also a fierce critic of emerging technological advancements, particularly the telephone, which he deemed a "a meddling device."
#
# Twain's personal life was marked by both triumphs and tragedies. He married Olivia Langdon in 1870 and had four children with her. The couple's relationship was seemingly ideal, with Twain describing their marriage as "a romance." However, their joy was short-lived as Olivia's health began to decline, and she passed away in 1904. Twain later married Isabel Lyon, a woman who was 20 years his junior, in 1904.
#
# Mark Twain died on April 21, 1910, in Redding, Connecticut, leaving behind a legacy as one of the greatest American writers. His works continue to be widely read and admired today, with "The Adventures of Tom Sawyer" and "The Adventures of Huckleberry Finn" topping the list of most enduring American novels. His wit, wisdom, and literary genius have made him an iconic figure in American literature, and his writing continues to inspire generations of writers, scholars, and readers alike.
#
#
# # Agent: agent role
# ## Task: a tldr summary of the short biography
#
#
# # Agent: agent role
# ## Final Answer:
# • Samuel Langhorne Clemens, better known by his pen name Mark Twain, was a renowned American author and humorist born on November 30, 1835, in Florida, Missouri.
# • He grew up in Hannibal, Missouri, a riverside town that would later serve as the inspiration for the fictional Tom Sawyer's hometown.
# • Clemens developed a fascination with steamboats and the Mississippi River, which played a significant role in shaping his literary career.
# • Before pursuing a career in writing, Clemens worked as a typesetter, a riverboat pilot, and a journalist.
# • He began his writing career as a newspaper reporter, eventually moving to Nevada and working as a correspondent for the Virginia City Territorial Enterprise.
